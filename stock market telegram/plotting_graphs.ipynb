# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:\\Users\\garya\\stock market telegram\dataset\\datasetbothQuartersWithDates.csv')
data
# Out:
#       Scrip_Name  Revenue_YOY  Revenue_Q1  Revenue_Q2  EBITDA_YOY  EBITDA_Q1  \
# 0      20MICRONS       517.00      154.15      159.21       66.00      19.88
# 1     21STCENMGM       -13.00       -3.92       -1.31      -15.00      -4.46
# 2      3IINFOLTD       212.00       62.58       68.62       -4.00      24.78
# 3        3MINDIA      3078.00      890.00      925.00      382.00     111.00
# 4         3PLAND         2.15        0.43        1.15        1.78       0.34
# ...          ...          ...         ...         ...         ...        ...
# 1714      ZOMATO      3611.00     1132.00     1178.00    -1627.00    -270.00
# 1715        ZOTA       131.00       29.49       38.57       15.00       2.07
# 1716       ZUARI        83.00       52.00       28.00      -12.00      -1.00
# 1717   ZYDUSLIFE      7982.00     1981.00     2399.00     1921.00     544.00
# 1718   ZYDUSWELL       216.00       62.00       67.00       -5.00       5.00
#
# ...

# %%
revenue = data['Revenue_Q1']
print(revenue)
price = data['After_Q1 (19-08-2022)']
# Out:
# 0        154.15
# 1         -3.92
# 2         62.58
# 3        890.00
# 4          0.43
#          ...
# 1714    1132.00
# 1715      29.49
# 1716      52.00
# 1717    1981.00
# 1718      62.00
# Name: Revenue_Q1, Length: 1719, dtype: float64

# %%
plt.scatter(revenue, price, s = 4)
