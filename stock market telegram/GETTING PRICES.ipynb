# %%
import requests

url = "https://alpha-vantage.p.rapidapi.com/query"

querystring = {"function":"TIME_SERIES_DAILY","symbol":"ACC","outputsize":"compact","datatype":"json"}

headers = {
	"X-RapidAPI-Key": "35fde04bb4mshf458611efe7b6a0p1238b1jsn5716a18494b1",
	"X-RapidAPI-Host": "alpha-vantage.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {
#     "Meta Data": {
#         "1. Information": "Daily Prices (open, high, low, close) and Volumes",
#         "2. Symbol": "ACC",
#         "3. Last Refreshed": "2022-08-09",
#         "4. Output Size": "Compact",
#         "5. Time Zone": "US/Eastern"
#     },
#     "Time Series (Daily)": {
#         "2022-08-09": {
#             "1. open": "65.3700",
#             "2. high": "65.4600",
#             "3. low": "65.3700",
#             "4. close": "65.4200",
#             "5. volume": "18855710"
#         },
#         "2022-08-08": {
#             "1. open": "65.4100",
#             "2. high": "65.4200",
#             "3. low": "65.3700",
#             "4. close": "65.3700",
#             "5. volume": "3017037"
#         },
#         "2022-08-05": {
#             "1. open": "65.4100",
#             "2. high": "65.4100",
#             "3. low": "65.3800",
#             "4. close": "65.4000",
#             "5. volume": "1940820"
#         },
#         "2022-08-04": {
# ...

# %%
len(response.text)
# Out:
# 20868

# %%
# Out:
# {
#     "Meta Data": {
#         "1. Information": "Weekly Prices (open, high, low, close) and Volumes",
#         "2. Symbol": "MSFT",
#         "3. Last Refreshed": "2022-11-18",
#         "4. Time Zone": "US/Eastern"
#     },
#     "Weekly Time Series": {
#         "2022-11-18": {
#             "1. open": "241.9850",
#             "2. high": "247.0000",
#             "3. low": "237.6300",
#             "4. close": "241.2200",
#             "5. volume": "137343796"
#         },
#         "2022-11-11": {
#             "1. open": "221.9900",
#             "2. high": "247.9900",
#             "3. low": "221.2800",
#             "4. close": "247.1100",
#             "5. volume": "170431704"
#         },
#         "2022-11-04": {
#             "1. open": "233.7600",
#             "2. high": "235.7400",
#             "3. low": "213.4310",
#             "4. close": "221.3900",
#             "5. volume": "170779529"
#         },
#         "2022-10-28": {
# ...

# %%
import requests
import pandas as pd
import time

scrip_codes = pd.read_csv("C:\\Users\\garya\\stock market telegram\\CN500.csv")
list1 = []
url = "https://alpha-vantage.p.rapidapi.com/query"
headers = {
        "X-RapidAPI-Key": "05f505c6e0msh76838e268b44175p1d9934jsn139a2a60a05c",
        "X-RapidAPI-Host": "alpha-vantage.p.rapidapi.com"
}
for symbol in scrip_codes['ScripName']:
    try:
        querystring = {"function":"TIME_SERIES_WEEKLY","symbol":symbol,"datatype":"json"}
        response = requests.request("GET", url, headers=headers, params=querystring)
        print(symbol)
        data = response.json()
        print(data)
        QUARTER2_END = '2022-11-18'
        QUARTER2_START = '2022-10-07'
        QUARTER1_END = '2022-08-19'
        QUARTER1_START = '2022-07-01'
        after_q2 = data['Weekly Time Series'][QUARTER2_END]['4. close']
        before_q2 = data['Weekly Time Series'][QUARTER2_START]['4. close']
        after_q1 = data['Weekly Time Series'][QUARTER1_END]['4. close']
        before_q1 = data['Weekly Time Series'][QUARTER1_START]['4. close']
        temp_data = {
            'ScripName' : symbol,
            'BEFORE_Q1_RESULTS': before_q1, 
            'AFTER_Q1_RESULTS' : after_q1,
            'BEFORE_Q2_RESULTS' : before_q2,
            'After_Q2_RESULTS': after_q2
        }
        temp_df = pd.DataFrame(temp_data, index = [1])
        list1.append(temp_df)
#         print(after_q2, before_q2, after_q1, before_q1)
    except Exception as e:
        print(symbol, e)
    finally:
        time.sleep(15)
# Out:
# 3MINDIA
# {'Error Message': 'Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for TIME_SERIES_WEEKLY.'}
# 3MINDIA 'Weekly Time Series'
# AARTIDRUGS
# {'Error Message': 'Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for TIME_SERIES_WEEKLY.'}
# AARTIDRUGS 'Weekly Time Series'
# AAVAS
# {'Error Message': 'Invalid API call. Please retry or visit the documentation (https://www.alphavantage.co/documentation/) for TIME_SERIES_WEEKLY.'}
# AAVAS 'Weekly Time Series'
# ABB
# ...

# %%
print(list1)
# Out:
# [  ScripName BEFORE_Q1_RESULTS AFTER_Q1_RESULTS BEFORE_Q2_RESULTS  \
# 1       ABB           26.6100          29.7200           25.0100
#
#   After_Q2_RESULTS
# 1          30.7200  ]
