# %%
import pandas as pd 
import datetime
from dateutil.relativedelta import relativedelta

# %%
df = pd.read_csv(r"C:\Users\garya\ML projects\Stock analysis\datasets\tempdata\16categories\category_number_0.csv")
temp = df[df['Quarter'] == 'Dec 2019 - Mar 2020']
temp = temp[temp['SYMBOL'] == 'VEDL']
temp
# Out:
#      SYMBOL Company Name Company Code              Quarter Result Date  \
# 3953   VEDL      vedanta           SG  Dec 2019 - Mar 2020  06-06-2020
#
#       Price on Result Date  High in next 90 days  Low in next 90 days  \
# 3953                 105.3                 132.0               101.05
#
#         Change
# 3953  0.253561

# %%
# Out:
# Empty DataFrame
# Columns: [SYMBOL, Company Name, Company Code, Quarter, Result Date, Price on Result Date, High in next 90 days, Low in next 90 days, Change]
# Index: []

# %%
def getQuarters(curDate, prevDate):
    
    prevMon = prevDate.strftime("%b")
    curMon = curDate.strftime("%b")
    prevYear = prevDate.strftime("%Y")
    curYear = curDate.strftime("%Y")
    curQuarter = f"{curMon} {curYear}"
    prevQuarter = f"{prevMon} {prevYear}"
    return curQuarter, prevQuarter

def quarterList():
    lst = []
    date = datetime.datetime(2022,12,1)
    minDate = datetime.datetime(2017,1,1)
    while(date > minDate):
        prevDate = date-relativedelta(months=3)
        curQuarter, prevQuarter = getQuarters(date, prevDate)
        lst.append([curQuarter, prevQuarter])
        date = prevDate
    return lst

# %%
quarterlist = quarterList()

# %%
quarterlist
# Out:
# [['Dec 2022', 'Sep 2022'],
#  ['Sep 2022', 'Jun 2022'],
#  ['Jun 2022', 'Mar 2022'],
#  ['Mar 2022', 'Dec 2021'],
#  ['Dec 2021', 'Sep 2021'],
#  ['Sep 2021', 'Jun 2021'],
#  ['Jun 2021', 'Mar 2021'],
#  ['Mar 2021', 'Dec 2020'],
#  ['Dec 2020', 'Sep 2020'],
#  ['Sep 2020', 'Jun 2020'],
#  ['Jun 2020', 'Mar 2020'],
#  ['Mar 2020', 'Dec 2019'],
#  ['Dec 2019', 'Sep 2019'],
#  ['Sep 2019', 'Jun 2019'],
#  ['Jun 2019', 'Mar 2019'],
#  ['Mar 2019', 'Dec 2018'],
#  ['Dec 2018', 'Sep 2018'],
#  ['Sep 2018', 'Jun 2018'],
#  ['Jun 2018', 'Mar 2018'],
#  ['Mar 2018', 'Dec 2017'],
#  ['Dec 2017', 'Sep 2017'],
#  ['Sep 2017', 'Jun 2017'],
#  ['Jun 2017', 'Mar 2017'],
#  ['Mar 2017', 'Dec 2016']]

# %%
for quarter in quarterlist:
    frames = []
    quarterPair  = f'{quarter[1]} - {quarter[0]}'
    for i in range(16):
        increaseCount = 0 
        decreaseCount = 0
        path = f"C:\\Users\\garya\\ML projects\\Stock analysis\\datasets\\16categories\\category_number_{i}.csv"
        df = pd.read_csv(path)
        df = df[df['Quarter'] == quarterPair]
        totalCount = len(df)
        print(totalCount)
        print(quarterPair)
        for j in range(totalCount):
            if(df['Change'].iloc[j] < 0):
                decreaseCount += 1
            else:
                increaseCount += 1
        if(totalCount == 0):
            totalCount = 1
        avg = df['Change'].mean()
        data = {
            "Category" : i, 
            "Decrease Percentage" : f"{round((decreaseCount*100)/totalCount,2)}%",
            "Increase Percentage": f"{round((increaseCount*100)/totalCount,2)}%", 
            "Average Change(%)": f"{round(avg*100,2)}%"
        }
        temp_df = pd.DataFrame(data, index=[1])
        frames.append(temp_df)
#         print(f"Catergory {i} :")
#         print(f"Total Count : {totalCount}")
#         print(f"Decrease Count : {decreaseCount} , Decrease Percentage : {round((decreaseCount*100)/totalCount,2)}% ")
#         print(f"Total Count : {totalCount} , Increase Percentage : {round((increaseCount*100)/totalCount,2)}%")
#         print(f"Average Change(%) : {round(avg*100,2)}%\n\n")
        
    final_df = pd.concat(frames, ignore_index = False)
    final_df.to_csv(f"C:\\Users\\garya\\ML projects\\Stock analysis\\datasets\\quarterWiseResults\\{quarterPair}.csv")
# Out:
# 0
# Sep 2022 - Dec 2022
# 0
# Sep 2022 - Dec 2022
# 0
# Sep 2022 - Dec 2022
# 0
# Sep 2022 - Dec 2022
# 0
# Sep 2022 - Dec 2022
# 0
# Sep 2022 - Dec 2022
# 0
# Sep 2022 - Dec 2022
# 0
# Sep 2022 - Dec 2022
# 0
# Sep 2022 - Dec 2022
# 0
# Sep 2022 - Dec 2022
# 0
# Sep 2022 - Dec 2022
# 0
# Sep 2022 - Dec 2022
# 0
# Sep 2022 - Dec 2022
# 0
# Sep 2022 - Dec 2022
# 0
# Sep 2022 - Dec 2022
# 0
# Sep 2022 - Dec 2022
# 251
# Jun 2022 - Sep 2022
# 43
# Jun 2022 - Sep 2022
# 0
# Jun 2022 - Sep 2022
# 18
# Jun 2022 - Sep 2022
# 140
# Jun 2022 - Sep 2022
# 3
# Jun 2022 - Sep 2022
# 16
# Jun 2022 - Sep 2022
# 28
# Jun 2022 - Sep 2022
# 30
# Jun 2022 - Sep 2022
# 5
# Jun 2022 - Sep 2022
# 5
# Jun 2022 - Sep 2022
# 79
# Jun 2022 - Sep 2022
# 18
# Jun 2022 - Sep 2022
# 0
# Jun 2022 - Sep 2022
# 71
# Jun 2022 - Sep 2022
# 403
# Jun 2022 - Sep 2022
# 282
# Mar 2022 - Jun 2022
# 46
# Mar 2022 - Jun 2022
# 4
# Mar 2022 - Jun 2022
# 25
# Mar 2022 - Jun 2022
# 115
# Mar 2022 - Jun 2022
# 0
# ...
