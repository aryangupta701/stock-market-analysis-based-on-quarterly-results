# %%
import pandas as pd

# %%
frames = []

for i in range(27):
    if( i == 26):
        page = "others"
    else:
        page = chr(65+i)
    try:
        df = pd.read_csv(f"C:\\Users\\garya\\ML projects\\Stock analysis\\datasets\\lists\\moneycontrollist{page}.csv")
        frames.append(df)
    except Exception as e:
        print(e)

# %%
final_df = pd.concat(frames, ignore_index = True)

# %%
final_df
# Out:
#                                                     URL  \
# 0     https://www.moneycontrol.com/india/stockpriceq...
# 1     https://www.moneycontrol.com/india/stockpriceq...
# 2     https://www.moneycontrol.com/india/stockpriceq...
# 3     https://www.moneycontrol.com/india/stockpriceq...
# 4     https://www.moneycontrol.com/india/stockpriceq...
# ...                                                 ...
# 5752  https://www.moneycontrol.com/india/stockpriceq...
# 5753  https://www.moneycontrol.com/india/stockpriceq...
# 5754  https://www.moneycontrol.com/india/stockpriceq...
# 5755  https://www.moneycontrol.com/india/stockpriceq...
# 5756  https://www.moneycontrol.com/india/stockpriceq...
#
#                         companysector            companyname companycode  \
# 0                       miscellaneous               amfebcon         F03
# 1                       miscellaneous            amjumbobags        JB03
# ...

# %%
final_df.to_csv("C:\\Users\\garya\\ML projects\\Stock analysis\\datasets\\moneyControlListWithSymbols.csv",index=False)
