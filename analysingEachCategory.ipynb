# %%
import pandas as pd

# %%
temp = 0
for i in range(16):
    increaseCount = 0 
    decreaseCount = 0
    path = f"C:\\Users\\garya\\ML projects\\Stock analysis\\datasets\\16categories\\category_number_{i}.csv"
    df = pd.read_csv(path)
    totalCount = len(df)
    temp += totalCount
    for j in range(totalCount):
        if(df['Change'][j] < 0):
            decreaseCount += 1
        else:
            increaseCount += 1
    avg = df['Change'].mean()
#     print(f"Catergory {i} :")
#     print(f"Total Count : {totalCount}")
#     print(f"Decrease Count : {decreaseCount} , Decrease Percentage : {round((decreaseCount*100)/totalCount,2)}% ")
#     print(f"Total Count : {totalCount} , Increase Percentage : {round((increaseCount*100)/totalCount,2)}%")
#     print(f"Average Change(%) : {round(avg*100,2)}%\n\n")
    
print(temp)
# Out:
# 14562

# %%
temp = 0
for i in range(16):
    increaseCount = 0 
    decreaseCount = 0
    path = f"C:\\Users\\garya\\ML projects\\Stock analysis\\datasets\\16categories\\category_number_{i}.csv"
    df = pd.read_csv(path)
    totalCount = len(df)
    temp += totalCount
    for j in range(totalCount):
        if(df['Change'][j] < 0):
            decreaseCount += 1
        else:
            increaseCount += 1
    avg = df['Change'].mean()
#     print(f"Catergory {i} :")
#     print(f"Total Count : {totalCount}")
#     print(f"Decrease Count : {decreaseCount} , Decrease Percentage : {round((decreaseCount*100)/totalCount,2)}% ")
#     print(f"Total Count : {totalCount} , Increase Percentage : {round((increaseCount*100)/totalCount,2)}%")
#     print(f"Average Change(%) : {round(avg*100,2)}%\n\n")
    
print(temp)
# Out:
# Catergory 0 :
# Total Count : 3708
# Decrease Count : 2048 , Decrease Percentage : 55.23%
# Total Count : 3708 , Increase Percentage : 44.77%
# Average Change(%) : -0.12%
#
#
# Catergory 1 :
# Total Count : 438
# Decrease Count : 228 , Decrease Percentage : 52.05%
# Total Count : 438 , Increase Percentage : 47.95%
# Average Change(%) : 3.22%
#
#
# Catergory 2 :
# Total Count : 52
# Decrease Count : 34 , Decrease Percentage : 65.38%
# Total Count : 52 , Increase Percentage : 34.62%
# Average Change(%) : -8.01%
#
#
# Catergory 3 :
# Total Count : 390
# Decrease Count : 215 , Decrease Percentage : 55.13%
# Total Count : 390 , Increase Percentage : 44.87%
# Average Change(%) : 3.57%
#
#
# Catergory 4 :
# Total Count : 1515
# Decrease Count : 897 , Decrease Percentage : 59.21%
# Total Count : 1515 , Increase Percentage : 40.79%
# Average Change(%) : -1.55%
#
#
# Catergory 5 :
# Total Count : 61
# Decrease Count : 33 , Decrease Percentage : 54.1%
# Total Count : 61 , Increase Percentage : 45.9%
# Average Change(%) : 6.32%
#
#
# Catergory 6 :
# Total Count : 222
# Decrease Count : 133 , Decrease Percentage : 59.91%
# Total Count : 222 , Increase Percentage : 40.09%
# Average Change(%) : -1.25%
#
#
# Catergory 7 :
# Total Count : 636
# Decrease Count : 341 , Decrease Percentage : 53.62%
# Total Count : 636 , Increase Percentage : 46.38%
# Average Change(%) : 4.58%
#
#
# Catergory 8 :
# Total Count : 578
# Decrease Count : 317 , Decrease Percentage : 54.84%
# Total Count : 578 , Increase Percentage : 45.16%
# Average Change(%) : 0.88%
#
#
# Catergory 9 :
# Total Count : 148
# Decrease Count : 84 , Decrease Percentage : 56.76%
# Total Count : 148 , Increase Percentage : 43.24%
# Average Change(%) : -1.43%
#
#
# Catergory 10 :
# Total Count : 97
# Decrease Count : 49 , Decrease Percentage : 50.52%
# Total Count : 97 , Increase Percentage : 49.48%
# Average Change(%) : 6.26%
#
#
# Catergory 11 :
# Total Count : 1168
# Decrease Count : 653 , Decrease Percentage : 55.91%
# Total Count : 1168 , Increase Percentage : 44.09%
# Average Change(%) : 1.84%
#
#
# Catergory 12 :
# Total Count : 524
# Decrease Count : 287 , Decrease Percentage : 54.77%
# Total Count : 524 , Increase Percentage : 45.23%
# Average Change(%) : 0.94%
#
#
# Catergory 13 :
# Total Count : 30
# Decrease Count : 14 , Decrease Percentage : 46.67%
# Total Count : 30 , Increase Percentage : 53.33%
# Average Change(%) : 13.6%
#
#
# Catergory 14 :
# Total Count : 744
# Decrease Count : 398 , Decrease Percentage : 53.49%
# Total Count : 744 , Increase Percentage : 46.51%
# Average Change(%) : 3.03%
#
#
# Catergory 15 :
# Total Count : 4251
# Decrease Count : 2048 , Decrease Percentage : 48.18%
# Total Count : 4251 , Increase Percentage : 51.82%
# Average Change(%) : 7.9%
